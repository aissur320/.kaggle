# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns

warnings.filterwarnings('ignore')

sns.set(style='white',context='notebook',palette='muted')
import matplotlib.pyplot as plt

train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
full_data = train.append(test,ignore_index=True)

# %%
display(full_data)
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
sns.barplot(data=train,x='Sex',y='Survived') # relationship between Sex and Survived
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
sum_Sex = full_data.groupby('Sex')['Survived'].value_counts().to_frame()
display(sum_Sex)
# Out:
#                  Survived
# Sex    Survived
# female 1.0            233
#        0.0             81
# male   0.0            468
#        1.0            109

# %%
rate_Sex = sum_Sex/sum_Sex.sum(level=0)
display(rate_Sex)
# Out:
#                  Survived
# Sex    Survived
# female 1.0       0.742038
#        0.0       0.257962
# male   0.0       0.811092
#        1.0       0.188908

# %%
pd.merge(sum_Sex,rate_Sex,left_index=True,right_index=True,suffixes=['_num','_rate'])
# Out:
#                  Survived_num  Survived_rate
# Sex    Survived
# female 1.0                233       0.742038
#        0.0                 81       0.257962
# male   0.0                468       0.811092
#        1.0                109       0.188908

# %%
sns.barplot(data=train,x='Pclass',y='Survived')
sum_Pclass = full_data.groupby('Pclass')['Survived'].value_counts().to_frame()
rate_Pclass = sum_Pclass/sum_Pclass.sum(level=0)
pd.merge(sum_Pclass,rate_Pclass,left_index=True,right_index=True,suffixes=['_num','_rate'])
# Out:
#                  Survived_num  Survived_rate
# Pclass Survived
# 1      1.0                136       0.629630
#        0.0                 80       0.370370
# 2      0.0                 97       0.527174
#        1.0                 87       0.472826
# 3      0.0                372       0.757637
#        1.0                119       0.242363

# %%
sns.catplot('Sex',col='Embarked',data=train,kind='count',size=5)

# %%
display(full_data)
